# %%
import pandas as pd
import os

# %%
ess_path = "../data/raw/ESS.csv"

# %%
ess_data = pd.read_csv(ess_path)

# %%
ess_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530711 entries, 0 to 530710
# Data columns (total 42 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   name      530711 non-null  object
#  1   essround  530711 non-null  int64
#  2   edition   530711 non-null  float64
#  3   proddate  530711 non-null  object
#  4   idno      530711 non-null  int64
#  5   cntry     530711 non-null  object
#  6   dweight   530711 non-null  float64
#  7   pspwght   530711 non-null  float64
#  8   pweight   530711 non-null  float64
#  9   anweight  440174 non-null  float64
#  10  prob      149360 non-null  float64
#  11  stratum   149360 non-null  float64
#  12  psu       149360 non-null  float64
#  13  netuse    235878 non-null  float64
#  14  netusoft  193747 non-null  float64
#  15  netustm   193747 non-null  float64
#  16  nwspol    193747 non-null  float64
#  17  nwsppol   242106 non-null  float64
#  18  nwsptot   242106 non-null  float64
# ...

# %%
html_data = pd.read_html("../data/raw/ESS.html")

# %%
ess_data["cntry"].unique()
# Out:
# array(['AT', 'BE', 'CH', 'CZ', 'DE', 'DK', 'ES', 'FI', 'FR', 'GB', 'GR',
#        'HU', 'IE', 'IL', 'IT', 'LU', 'NL', 'NO', 'PL', 'PT', 'SE', 'SI',
#        'EE', 'IS', 'SK', 'TR', 'UA', 'BG', 'CY', 'RU', 'HR', 'LV', 'RO',
#        'LT', 'AL', 'XK', 'ME', 'RS', 'MK'], dtype=object)

# %%
ess_data.head()
# Out:
#         name  essround  edition    proddate  idno cntry  dweight   pspwght  \
# 0  ESS1e06_7         1      6.7  23.11.2023     1    AT   0.9452  0.940933
# 1  ESS1e06_7         1      6.7  23.11.2023     2    AT   0.4726  0.470466
# 2  ESS1e06_7         1      6.7  23.11.2023     3    AT   0.9452  1.392155
# 3  ESS1e06_7         1      6.7  23.11.2023     4    AT   0.9452  1.382163
# 4  ESS1e06_7         1      6.7  23.11.2023     6    AT   1.8905  1.437766
#
#     pweight  anweight  ...  trstplc  trstplt  trstprt  trstun  trstsci  \
# 0  0.271487  0.255451  ...       10        0      NaN       9      NaN
# 1  0.271487  0.127726  ...        5        0      NaN       6      NaN
# 2  0.271487  0.377953  ...        8        2      NaN      88      NaN
# 3  0.271487  0.375240  ...        9        4      NaN       8      NaN
# 4  0.271487  0.390336  ...        4        4      NaN       5      NaN
#
#    loylead  medcrgv  medcrgvc  meprinf  implvdm
# ...

# %%
ess_data = ess_data.drop(labels=["name", "essround", "edition", "proddate"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ess_data = ess_data.drop(labels=["name", "essround", "edition", "proddate"], axis=1)
#
# File ~/DataScienceProjects/DOPP_Exercise2/.venv/lib/python3.10/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
ess_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530711 entries, 0 to 530710
# Data columns (total 38 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   idno      530711 non-null  int64
#  1   cntry     530711 non-null  object
#  2   dweight   530711 non-null  float64
#  3   pspwght   530711 non-null  float64
#  4   pweight   530711 non-null  float64
#  5   anweight  440174 non-null  float64
#  6   prob      149360 non-null  float64
#  7   stratum   149360 non-null  float64
#  8   psu       149360 non-null  float64
#  9   netuse    235878 non-null  float64
#  10  netusoft  193747 non-null  float64
#  11  netustm   193747 non-null  float64
#  12  nwspol    193747 non-null  float64
#  13  nwsppol   242106 non-null  float64
#  14  nwsptot   242106 non-null  float64
#  15  pplfair   530711 non-null  int64
#  16  pplhlp    530711 non-null  int64
#  17  ppltrst   530711 non-null  int64
#  18  rdpol     242106 non-null  float64
# ...

# %% [markdown]
# looking into the html to find interesting features:
#
# * nwsppol: Newspaper reading, politics/current affairs on average weekday
# * pplfair: Most people try to take advantage of you, or try to be fair
# * pplhlp: Most of the time people helpful or mostly looking out for themselves
# * ppltrst: Most people can be trusted or you can't be too careful
# * rdpol: Radio listening, news/politics/current affairs on average weekday
# * tvpol: TV watching, news/politics/current affairs on average weekday
# * dmcntov: How democratic [country] is overall
# * polintr: How interested in politics
# * stfdem: How satisfied with the way democracy works in country
# * stflife: How satisfied with life as a whole
# * trstep: Trust in the European Parliament
# * trstlgl: Trust in the legal system
# * trstplc: Trust in the police
# * trstplt: Trust in politicians
# * trstprt: Trust in political parties
# * trstsci: Trust in scientists
# * loylead: Country needs most loyalty towards its leaders
# * medcrgv: The media are free to criticise the government
# * medcrgvc: In country the media are free to criticise the government
# * meprinf: The media provide citizens with reliable information to judge the government
# * implvdm: How important for you to live in democratically governed country

# %%
selected_features = [
    "idno", "cntry", "dweight", "pspwght", "pweight", "anweight", "prob", "stratum", "psu", 'nwsppol', 'pplfair', 'pplhlp', 'ppltrst', 'rdpol', 'tvpol', 'dmcntov', 
    'polintr', 'stfdem', 'stflife', 'trstep', 'trstlgl', 'trstplc', 'trstplt', 
    'trstprt', 'trstsci', 'loylead', 'medcrgv', 'medcrgvc', 'meprinf', 'implvdm'
]

filtered_ess_data = ess_data[selected_features]
