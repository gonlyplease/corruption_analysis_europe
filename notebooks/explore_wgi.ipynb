# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_columns", None)

# %% [markdown]
# Source: https://www.worldbank.org/en/publication/worldwide-governance-indicators  <br>
#  <br>
# Estimate of governance in standard normal units ranging from approximately -2.5 (weak) to 2.5 (strong) governance performance. <br>
# <br>
# Years= [1996, 1998, 2000, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,<br>
#        2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,<br>
#        2021, 2022, 2023]<br>

# %%
wgi_data = pd.read_excel("../data/raw/wgidataset.xlsx")

# %%
wgi_data.drop(columns=["codeindyr", "stddev",	"nsource"	,"pctrank",	"pctranklower",	"pctrankupper"], inplace=True)

# %%
wgi_data.shape
# Out:
# (32100, 5)

# %%
wgi_data
wgi_data = wgi_data.pivot(index=["code", "countryname", "year"], columns="indicator", values="estimate").reset_index()
wgi_data.columns.name = None

rename_dict = {
    "cc": "control_of_corruption",
    "ge": "government_effectiveness",
    "pv": "political_stability_and_absence_of_violence_terrorism",
    "rl": "rule_of_law",
    "rq": "regulatory_quality",
    "va": "voice_and_accountability"
}
wgi_data = wgi_data.rename(columns=rename_dict)

wgi_data
# Out:
#      code countryname  year control_of_corruption government_effectiveness  \
# 0     ABW       Aruba  1996                    ..                       ..
# 1     ABW       Aruba  1998                    ..                       ..
# 2     ABW       Aruba  2000                    ..                       ..
# 3     ABW       Aruba  2002                    ..                       ..
# 4     ABW       Aruba  2003                    ..                       ..
# ...   ...         ...   ...                   ...                      ...
# 5345  ZWE    Zimbabwe  2019             -1.290334                -1.310435
# 5346  ZWE    Zimbabwe  2020             -1.308788                -1.342368
# 5347  ZWE    Zimbabwe  2021             -1.277147                -1.290561
# 5348  ZWE    Zimbabwe  2022             -1.259969                -1.251224
# 5349  ZWE    Zimbabwe  2023             -1.261216                -1.170335
#
# ...

# %%
wgi_data["code"].unique()
# Out:
# array(['ABW', 'ADO', 'AFG', 'AGO', 'AIA', 'ALB', 'ANT', 'ARE', 'ARG',
#        'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN',
#        'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU',
#        'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE',
#        'CHL', 'CHN', 'CIV', 'CMR', 'COG', 'COK', 'COL', 'COM', 'CPV',
#        'CRI', 'CUB', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA', 'DNK',
#        'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN',
#        'FJI', 'FRA', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIN', 'GMB',
#        'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUF', 'GUM', 'GUY',
#        'HKG', 'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IND', 'IRL', 'IRN',
#        'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JEY', 'JOR', 'JPN', 'KAZ',
#        'KEN', 'KGZ', 'KHM', 'KIR', 'KNA', 'KOR', 'KSV', 'KWT', 'LAO',
#        'LBN', 'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX',
# ...
